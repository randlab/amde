# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Probabilité
#
# Exemple pour un calcul de probabilité sur une variable discrète.

# %%
data = np.loadtxt('FontaineVauclusePluieDebit.txt', skiprows=2)
jour = data[:,0]
pluie = data[:,2]
plt.plot(jour, pluie)
plt.show()

# %% [markdown]
# But : Estimer la probabilité qu'il pleuve si on prend un jour au hasard.

# %%
np.sum( pluie > 0 ) / len(pluie)
# Out:
# 0.3759124087591241

# %%
proba_pluie = np.sum( pluie > 0 ) / len(pluie)
print('la probabilité estimée est de', proba_pluie)
# Out:
# la probabilité estimée est de 0.3759124087591241

# %% [markdown]
# # Tirage aléatoire
#
# Tirage de valeurs à l'intérieur d'un tableau, pour réaliser des expériences.

# %%
pv = np.loadtxt('pluie_moyenne_CH.txt')
print( np.mean(pv) )
# Out:
# 1396.752278727423

# %%
echantillon = np.random.choice(pv,10)
moyenne_echantillon = np.mean( echantillon )
print( moyenne_echantillon )
# Out:
# 1361.6602966308594
